# %%
def server() -> None:
    from logging import basicConfig, INFO

    basicConfig(level=INFO)

    from topolink import Graph

    node_names = ["1", "2", "3", "4", "5"]
    edge_pairs = [("1", "2"), ("2", "3"), ("3", "4"), ("4", "5"), ("5", "1")]

    graph = Graph(node_names, edge_pairs, address="localhost:5555")

    graph.plot()

    graph.deploy()


server()
# Out:
# INFO:root:Server running on localhost:5555
# INFO:root:Node 2 registered with address 172.20.33.166:40783
# INFO:root:Node 4 registered with address 172.20.33.166:35987
# INFO:root:Node 1 registered with address 172.20.33.166:35789
# INFO:root:Node 3 registered with address 172.20.33.166:44465
# INFO:root:Node 5 registered with address 172.20.33.166:34027
# INFO:root:All nodes registered. Server is now ready.
# INFO:root:Sent neighbor addresses to all nodes.
