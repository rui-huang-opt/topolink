# %% [markdown]
# # Test for consensus
#
# This notebook documents the server-side implementation for the consensus test.

# %%
def server() -> None:
    from logging import basicConfig, INFO

    basicConfig(level=INFO)

    from topolink import Graph

    node_names = ["1", "2", "3", "4", "5"]
    edge_pairs = [("1", "2"), ("2", "3"), ("3", "4"), ("4", "5"), ("5", "1")]

    graph = Graph(node_names, edge_pairs, address="localhost:5555")

    graph.plot()

    graph.deploy()


server()
# Out:
# INFO:root:Server running on localhost:5555
# INFO:root:Node 4 registered with address 192.168.1.100:54237
# INFO:root:Node 1 registered with address 192.168.1.100:54279
# INFO:root:Node 5 registered with address 192.168.1.100:55289
# INFO:root:Node 2 registered with address 192.168.1.100:56001
# INFO:root:Node 3 registered with address 192.168.1.100:54441
# INFO:root:All nodes registered. Server is now ready.
# INFO:root:Sent neighbor addresses to all nodes.
# INFO:root:Node 1 has shut down.
# INFO:root:Node 4 has shut down.
# INFO:root:Node 3 has shut down.
# INFO:root:Node 5 has shut down.
# INFO:root:Node 2 has shut down.
# INFO:root:Sent shutdown confirmation to 2
# INFO:root:Sent shutdown confirmation to 1
# INFO:root:Sent shutdown confirmation to 3
# INFO:root:Sent shutdown confirmation to 5
# INFO:root:Sent shutdown confirmation to 4
