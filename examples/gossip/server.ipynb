# %% [markdown]
# # Test for consensus
#
# This notebook documents the server-side implementation for the consensus test.

# %%
def server() -> None:
    from logging import basicConfig, INFO

    basicConfig(level=INFO)

    from topolink import Graph

    node_names = ["1", "2", "3", "4", "5"]
    edge_pairs = [("1", "2"), ("2", "3"), ("3", "4"), ("4", "5"), ("5", "1")]

    graph = Graph(node_names, edge_pairs, address="localhost:5555")

    graph.plot()

    graph.deploy()


server()
# Out:
# INFO:root:Server running on localhost:5555
# INFO:root:Node 4 registered with address 10.20.107.251:54475
# INFO:root:Node 3 registered with address 10.20.107.251:55977
# INFO:root:Node 1 registered with address 10.20.107.251:55741
# INFO:root:Node 2 registered with address 10.20.107.251:56187
# INFO:root:Node 5 registered with address 10.20.107.251:55277
# INFO:root:All nodes registered. Server is now ready.
# INFO:root:Sent neighbor addresses to all nodes.
# INFO:root:Node 4 has unregistered.
# INFO:root:Node 1 has unregistered.
# INFO:root:Node 3 has unregistered.
# INFO:root:Node 2 has unregistered.
# INFO:root:Node 5 has unregistered.
