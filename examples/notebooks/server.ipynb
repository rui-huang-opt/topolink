# %% [markdown]
# # Test for consensus
#
# This notebook documents the server-side implementation for the consensus test.

# %%
def server() -> None:
    from logging import basicConfig, INFO
    import matplotlib.pyplot as plt

    basicConfig(level=INFO)

    from topolink import Graph

    node_names = ["1", "2", "3", "4", "5"]
    edge_pairs = [("1", "2"), ("2", "3"), ("3", "4"), ("4", "5"), ("5", "1")]

    graph = Graph(node_names, edge_pairs, address="localhost:5555")

    _, ax = plt.subplots()

    graph.draw(ax)

    plt.show()

    graph.deploy()


server()
# Out:
# INFO:topolink.Graph:Server running on localhost:5555
# INFO:topolink.Graph:Node 5 registered with address 192.168.1.100:53216
# INFO:topolink.Graph:Node 3 registered with address 192.168.1.100:54530
# INFO:topolink.Graph:Node 2 registered with address 192.168.1.100:54428
# INFO:topolink.Graph:Node 4 registered with address 192.168.1.100:53916
# INFO:topolink.Graph:Node 1 registered with address 192.168.1.100:54272
# INFO:topolink.Graph:All nodes registered. Server is now ready.
# INFO:topolink.Graph:Sent neighbor addresses to all nodes.
# INFO:topolink.Graph:Node 4 has unregistered.
# INFO:topolink.Graph:Node 3 has unregistered.
# INFO:topolink.Graph:Node 2 has unregistered.
# INFO:topolink.Graph:Node 5 has unregistered.
# INFO:topolink.Graph:Node 1 has unregistered.
